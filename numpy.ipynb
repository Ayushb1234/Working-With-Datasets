# %%
import numpy as np

# %%
arr = np.array([[[1, 2, 3, 4, 5]]])
print(arr)
# Out:
# [[[1 2 3 4 5]]]

# %%
print(arr.ndim)
# Out:
# 3

# %%
print(arr.shape)
# Out:
# (1, 1, 5)

# %%
range = np.arange(1,30,30)
print(range)
# Out:
# [1]
