# %%
import pandas as pd

import numpy as np

s= pd.Series()

print(s)

data = np.array(['a','x','e','m'])  
s2 = pd.Series(data)
print(s2)
# Out:
# Series([], dtype: object)
# 0    a
# 1    x
# 2    e
# 3    m
# dtype: str

# %%
df = pd.DataFrame()
print(df)
